# %%
# %pylab inline
import string
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class Pokemon:
    def __init__(self):
        self.catch_rate = random.random()
        self.name = self.gen_name()
        
    def __repr__(self):
        return self.name
        
    def gen_name(self):
        res = ''
        for i in range(5):
            if i%2==0:
                res += ''.join(np.random.choice(list(consonants),1))
            else:
                res += ''.join(np.random.choice(list(vowels), np.random.randint(1,3)))
        res+='mon'
        return res

# %%
Pokemon()
# Out:
# buafokmon

# %%
import bs4
import requests

# %%
response = requests.get('https://bulbapedia.bulbagarden.net/wiki/List_of_moves')

# %%
soup = bs4.BeautifulSoup(response.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of moves - Bulbapedia, the community-driven Pokémon encyclopedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
import pandas as pd

# %%
soup.find('table')
# Out:
# <table class="sortable roundy" style="margin:auto; background: #ddf; border: 5px solid #ccf">
# <tr>
# <td>
# <table border="1" class="sortable roundy" style="margin:auto; background: #FFF; border:1px solid #ddf; border-collapse:collapse" width="100%">
# <tr style="background: #ddf">
# <th style="width: 30px">#
# </th>
# <th style="width: 160px">Name
# </th>
# <th style="width: 60px"><a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a>
# </th>
# <th style="width: 60px"><a href="/wiki/Damage_category" title="Damage category"><span style="color:#000;">Category</span></a>
# </th>
# <th style="width: 60px"><a href="/wiki/Contest_condition" title="Contest condition"><span style="color:#000;">Contest</span></a>
# </th>
# <th style="width: 40px"><a href="/wiki/Power_Point" title="Power Point"><span style="color:#000;">PP</span></a>
# </th>
# <th style="width: 40px"><a href="/wiki/Power" title="Power"><span style="color:#000;">Power</span></a>
# </th>
# ...
